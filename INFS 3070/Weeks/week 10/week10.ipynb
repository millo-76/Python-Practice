# %% [markdown]
# # Week 10

# %% [markdown]
# ## Functions

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("http://128.198.162.191/dataFiles/HURRICANES/hurdat2-1851-2023-051124.txt")

df.head()
# Out:
#                                                                                                            AL011851  \
# 18510625 0000   HU 28.0N 94.8W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#          0600   HU 28.0N 95.4W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#          1200   HU 28.0N 96.0W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#          1800   HU 28.1N 96.5W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#          2100 L HU 28.2N 96.8W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0    -999.0
#
#                                                                                                                        UNNAMED  \
# 18510625 0000   HU 28.0N 94.8W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0               -999.0
#          0600   HU 28.0N 95.4W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0               -999.0
#          1200   HU 28.0N 96.0W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0               -999.0
#          1800   HU 28.1N 96.5W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0               -999.0
#          2100 L HU 28.2N 96.8W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0               -999.0
#
#                                                                                                                 14  \
# 18510625 0000   HU 28.0N 94.8W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0   -999.0
#          0600   HU 28.0N 95.4W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0   -999.0
#          1200   HU 28.0N 96.0W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0   -999.0
#          1800   HU 28.1N 96.5W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0   -999.0
#          2100 L HU 28.2N 96.8W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0   -999.0
#
#                                                                                                            Unnamed: 3
# 18510625 0000   HU 28.0N 94.8W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0      -999.0
#          0600   HU 28.0N 95.4W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0      -999.0
#          1200   HU 28.0N 96.0W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0      -999.0
#          1800   HU 28.1N 96.5W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0      -999.0
#          2100 L HU 28.2N 96.8W 80.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0 -999.0      -999.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 56721 entries, ('18510625', ' 0000', '  ', ' HU', ' 28.0N', '  94.8W', np.float64(80.0), np.float64(-999.0), np.float64(-999.0), np.float64(-999.0), np.float64(-999.0), np.float64(-999.0), np.float64(-999.0), np.float64(-999.0), np.float64(-999.0), np.float64(-999.0), np.float64(-999.0)) to ('20231024', ' 1200', '  ', ' LO', ' 13.5N', '  84.4W', np.float64(20.0), np.float64(1007.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0), np.float64(0.0))
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AL011851             54749 non-null  float64
#  1               UNNAMED  54749 non-null  float64
#  2        14              54749 non-null  float64
#  3   Unnamed: 3           54749 non-null  float64
# dtypes: float64(4)
# memory usage: 3.6+ MB

# %% [markdown]
# ### Add colum names

# %%
filepath = "http://128.198.162.191/dataFiles/HURRICANES/hurdat2-1851-2023-051124.txt"

column_names = [
    "ID-Date", "Time", "Record Identifier", "Status", "Latitude", "Longitude",
    "Windspeed", "Pressure", "extra1", "extra2", "extra3", "extra4", "extra5",
    "extra6", "extra7", "extra8", "extra9", "extra10", "extra11", "extra12"
]

df = pd.read_csv(filepath, header=0, names=column_names, usecols=range(len(column_names)), on_bad_lines='skip')

df.head()
# Out:
#     ID-Date   Time Record Identifier Status Latitude Longitude  Windspeed  \
# 0  18510625   0000                       HU    28.0N     94.8W       80.0
# 1  18510625   0600                       HU    28.0N     95.4W       80.0
# 2  18510625   1200                       HU    28.0N     96.0W       80.0
# 3  18510625   1800                       HU    28.1N     96.5W       80.0
# 4  18510625   2100                 L     HU    28.2N     96.8W       80.0
#
#    Pressure  extra1  extra2  extra3  extra4  extra5  extra6  extra7  extra8  \
# 0    -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0
# 1    -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0
# 2    -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0
# 3    -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0
# 4    -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0  -999.0
#
#    extra9  extra10  extra11  extra12
# 0  -999.0   -999.0   -999.0   -999.0
# 1  -999.0   -999.0   -999.0   -999.0
# 2  -999.0   -999.0   -999.0   -999.0
# 3  -999.0   -999.0   -999.0   -999.0
# 4  -999.0   -999.0   -999.0   -999.0

# %% [markdown]
# ### Extract "ID", "YEAR", and "MONTH"

# %%
# Create colums to cteate "ID", "YEAR", and "MONTH"
df['YEAR'] = ""
df['MONTH'] = ""

# only extract year and month where ID-Date doesn not contain AL
df.loc[~df['ID-Date'].str.contains('AL'), 'YEAR'] = df['ID-Date'].str[:4]
df.loc[~df['ID-Date'].str.contains('AL'), 'MONTH'] = df['ID-Date'].str[4:6]

# create a new  UNIQUE_ID column
df['UNIQUE_ID'] = df['ID-Date'].apply(lambda x: x if 'AL' in x else None)

# forward fill the UNIQUE_ID column to propagate the hurricane ID to all rows
df['UNIQUE_ID'] = df['UNIQUE_ID'].ffill()

df.head()
# Out:
#     ID-Date   Time Record Identifier Status Latitude Longitude  Windspeed  \
# 0  18510625   0000                       HU    28.0N     94.8W       80.0
# 1  18510625   0600                       HU    28.0N     95.4W       80.0
# 2  18510625   1200                       HU    28.0N     96.0W       80.0
# 3  18510625   1800                       HU    28.1N     96.5W       80.0
# 4  18510625   2100                 L     HU    28.2N     96.8W       80.0
#
#    Pressure  extra1  extra2  ...  extra6  extra7  extra8  extra9  extra10  \
# 0    -999.0  -999.0  -999.0  ...  -999.0  -999.0  -999.0  -999.0   -999.0
# 1    -999.0  -999.0  -999.0  ...  -999.0  -999.0  -999.0  -999.0   -999.0
# 2    -999.0  -999.0  -999.0  ...  -999.0  -999.0  -999.0  -999.0   -999.0
# 3    -999.0  -999.0  -999.0  ...  -999.0  -999.0  -999.0  -999.0   -999.0
# 4    -999.0  -999.0  -999.0  ...  -999.0  -999.0  -999.0  -999.0   -999.0
#
#    extra11  extra12  YEAR  MONTH  UNIQUE_ID
# 0   -999.0   -999.0  1851     06       None
# 1   -999.0   -999.0  1851     06       None
# 2   -999.0   -999.0  1851     06       None
# 3   -999.0   -999.0  1851     06       None
# 4   -999.0   -999.0  1851     06       None
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Total hurricanes per year

# %%
hurricanesByYear = df.groupby('YEAR')['UNIQUE_ID'].count().reset_index(name='COUNT')

hurricanesByYear
# Out:
#      YEAR  COUNT
# 0           1972
# 1    1851     84
# 2    1852    134
# 3    1853    100
# 4    1854     60
# ..    ...    ...
# 169  2019    493
# 170  2020    883
# 171  2021    602
# 172  2022    471
# 173  2023    773
#
# [174 rows x 2 columns]

# %% [markdown]
# ### Visualize by Year

# %%
df['YEAR'] = pd.to_numeric(df['YEAR'], errors='coerce')

# drop rows with NaN values in 'YEAR' column
dfClean = df.dropna(subset=['YEAR'])

# convert 'YEAR' column to integer type
dfClean.loc[:, 'YEAR'] = dfClean['YEAR'].astype(int)

# group the cleaned DataFrame
hurricanesByYear = dfClean.groupby('YEAR')['UNIQUE_ID'].nunique()

# plot results
plt.figure(figsize=(10, 5))
plt.plot(hurricanesByYear.index, hurricanesByYear.values, marker='o')

plt.xlabel('Year')
plt.ylabel('Number of Hurricanes')
plt.title('Total Number of Hurricanes by Year')

plt.gca().xaxis.set_major_locator(plt.MultipleLocator(5))
plt.xticks(rotation=45)

plt.grid(True)
plt.show()

# %%
# add averasge line

# plot results
plt.figure(figsize=(10, 5))
plt.plot(hurricanesByYear.index, hurricanesByYear.values, marker='o')

# add an average line
cumulative_avg = hurricanesByYear.expanding().mean()

plt.plot(cumulative_avg.index, cumulative_avg.values, color='red', linestyle='--', label='Cumulative Average')

plt.xlabel('Year')
plt.ylabel('Number of Hurricanes')
plt.title('Total Number of Hurricanes by Year')

plt.gca().xaxis.set_major_locator(plt.MultipleLocator(5))
plt.xticks(rotation=45)

plt.grid(True)
plt.show()
